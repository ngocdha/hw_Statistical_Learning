# %%
library(ggplot2)

# %%
attach(mtcars)
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg

# %%
ggplot(mtcars, aes(x=wt,y=mpg,size=hp)) + geom_point()
# Out:
# plot without title

# %%
attach(iris)

# %%
ggplot(iris,aes(x=Sepal.Length, y=Petal.Length),color=Species) + geom_point()
# Out:
# plot without title

# %%
plot(mpg~wt)
out <- lm(mpg~wt)
abline(out$coefficients[1],out$coefficients[2],lwd=2, col="red")
# Out:
# plot without title

# %%
par(mfrow=c(2,2))
plot(out)
# Out:
# Plot with title ""

# %%
outt = table(carb,cyl)
plot(outt)
# Out:
# Plot with title "outt"
